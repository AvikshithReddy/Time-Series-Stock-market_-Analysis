# %% [markdown]
# Everyone into the **Stock Markets** these days and I got curious as well. How do stocks could be analyzed? Even though I am pretty sure I did a good job in a process, but I would not use it as a 100% sure thing to invest😊. And in a process, I learned a lot of Python which is always a good thing.
#
# In this kernel, I would take a look at the latest **Shopify**, **JD.com** and **Alibaba** stocks data beginning from 2015.
#
# **Shopify** is a multinational Canadian e-commerce company with headquarters in Ottawa, Ontario that was founded in 2004. The company offers business e-commerce platforms for online stores, including payments, marketing, shipping and customer engagement tools to simplify the process of running an online store for small merchants. In 2019 Shopify announced reaching over 1,000,000 businesses in approximately 175 countries.
# **JD.com** is an e-commerce Chinese company headquartered in Beijing that was founded in 1998. It is one of two huge business-to-consumer online retailers, a member of Fortune Global 500 with a total revenue of $67 billion in 2018.
#
# **Alibaba** is the second top e-commerce and technology company in China and a major competitor to JD.com. It was created in 1999 and it's now headquartered in Hangzhou. The company offers sales services via web portals such as business-to-business, business-to-consumer, and consumer-to-consumer, as well as electronic payment services, shopping search engines, and cloud computing services. It' revenue in 2019 was over $56 billion.

# %% [markdown]
# Ok. Here we go...

# %%
pip install pandas-datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#importing all of the neccesary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import pandas_datareader
import datetime

import pandas_datareader.data as web

# %% [markdown]
# To keep the dataset up to date, I decided to use .today() instead of just setting an exact date. Now it always has the latest data.

# %%
#creating a start and an end dates:
start = datetime.datetime(2024,1,1)
end = datetime.datetime.today()

# %% [markdown]
# The next step will be downloading the data. I used 'yahoo' as a source since 'google' would result in "*NotImplementedError: data_source='google' is not implemented*"
# Tickers for the stocks can be found online. I found mine by just googling the company names.

# %%
# !pip install yfinance
import yfinance as yf

# %%
# Shopify
#shop = web.DataReader("SHOP", "yahoo", start, end)
 # shop.head()

# %%
# Fetch the data using yfinance
shop = yf.download("SHOP", start=start, end=end)
print(shop.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker           SHOP       SHOP       SHOP       SHOP      SHOP
# Date
# 2024-01-02  73.830002  76.629997  72.910004  76.440002  13134800
# 2024-01-03  71.820000  72.989998  71.180000  72.080002   9649900
# 2024-01-04  73.419998  74.019997  70.614998  71.629997  11927400
# 2024-01-05  74.510002  75.946999  73.000000  73.320000   9830200
# 2024-01-08  77.690002  77.900002  74.720001  74.779999   8232000

# %%
#JD.com
jd = yf.download('JD', start, end)
jd.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker             JD         JD         JD         JD        JD
# Date
# 2024-01-02  25.684736  26.468498  25.599750  26.440169  15718200
# 2024-01-03  25.939695  26.005797  25.325906  25.448665  12776300
# 2024-01-04  25.646963  25.939693  25.552534  25.788607   8080700
# 2024-01-05  25.193705  25.543092  25.019011  25.514764  13276500
# 2024-01-08  24.513813  24.603522  23.815037  23.999176  15459000

# %%
#Alibaba
alibaba = yf.download('BABA', start, end)
alibaba.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker           BABA       BABA       BABA       BABA      BABA
# Date
# 2024-01-02  73.169769  74.456793  72.925087  74.432330  21739600
# 2024-01-03  74.960838  75.058717  72.494445  72.748917  24444600
# 2024-01-04  73.071899  74.114241  72.856578  73.952749  18454900
# 2024-01-05  71.456993  72.425933  71.310182  72.425933  21679000
# 2024-01-08  71.329758  71.505929  69.411450  69.734432  22000000

# %% [markdown]
# ***Stock Market Data Visualization***

# %% [markdown]
# Key Findings:
#
# Alibaba and Shopify experienced significantly higher volatility in opening prices compared to JD.com.
#
# Alibaba's stock saw a sharp rise between September and December 2024, peaking above $140 before experiencing a correction.
#
# Shopify's opening prices fluctuated within the $60–$120 range, showing moderate growth trends.
#
# JD.com maintained a more stable and lower price range ($20–$45), with less dramatic movements than the other two.

# %% [markdown]
# Key Findings:
#
# Alibaba experienced the most frequent spikes in trading volume, possibly due to major news, earnings reports, or market reactions.
#
# Shopify had several volume surges, especially around May and late 2024, indicating increased market interest or volatility.
#
# JD.com showed fewer extreme spikes but maintained a consistent trading volume trend throughout the period.

# %% [markdown]
# Now let's plot the Volume of each stock that was traded every day

# %%
# Plot 1: Opening Prices
plt.figure(figsize=(16,10))
plt.plot(shop['Open'], label='Shopify')
plt.plot(jd['Open'], label='JD.com')
plt.plot(alibaba['Open'], label='Alibaba')
plt.title('Opening Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Opening Price (USD)')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# Plot 2: Volume Traded
plt.figure(figsize=(16,10))
plt.plot(shop['Volume'], label='Shopify')
plt.plot(jd['Volume'], label='JD.com')
plt.plot(alibaba['Volume'], label='Alibaba')
plt.title('Trading Volume Over Time')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %% [markdown]
# While Alibaba and Shopify have higher price ranges and volatility, JD.com appears more stable in both price and trading activity.
#
# These trends may suggest that Alibaba is more reactive to market events, whereas JD.com might appeal to investors preferring lower volatility.

# %%
print(type(shop['Volume']))
print(shop['Volume'].head())
print(shop['Volume'].shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Ticker          SHOP
# Date
# 2024-01-02  13134800
# 2024-01-03   9649900
# 2024-01-04  11927400
# 2024-01-05   9830200
# 2024-01-08   8232000
# (354, 1)

# %%
# Step 1: Flatten columns if multi-level (e.g., Ticker in column names)
if isinstance(shop.columns, pd.MultiIndex):
    shop.columns = shop.columns.get_level_values(0)

if isinstance(jd.columns, pd.MultiIndex):
    jd.columns = jd.columns.get_level_values(0)

if isinstance(alibaba.columns, pd.MultiIndex):
    alibaba.columns = alibaba.columns.get_level_values(0)

# Step 2: Reset index to ensure single-column index (optional but useful for plotting/export)
shop = shop.reset_index()
jd = jd.reset_index()
alibaba = alibaba.reset_index()

# Step 3: Confirm 'Volume' is now a Series
shop['Volume'] = shop['Volume'].astype(float)
jd['Volume'] = jd['Volume'].astype(float)
alibaba['Volume'] = alibaba['Volume'].astype(float)

# Step 4: Recompute 'Avg' and 'Total Traded New'
shop['Avg'] = (shop['High'] + shop['Low']) / 2
jd['Avg'] = (jd['High'] + jd['Low']) / 2
alibaba['Avg'] = (alibaba['High'] + alibaba['Low']) / 2

shop['Total Traded New'] = shop['Avg'] * shop['Volume']
jd['Total Traded New'] = jd['Avg'] * jd['Volume']
alibaba['Total Traded New'] = alibaba['Avg'] * alibaba['Volume']

# %%
print(type(shop['Volume']))         # should be <class 'pandas.core.series.Series'>
print(shop['Volume'].shape)        # should be (354,)
print(shop[['Date', 'Volume']].head())
# Out:
# <class 'pandas.core.series.Series'>
# (354,)
# Price       Date      Volume
# 0     2024-01-02  13134800.0
# 1     2024-01-03   9649900.0
# 2     2024-01-04  11927400.0
# 3     2024-01-05   9830200.0
# 4     2024-01-08   8232000.0

# %%
shop['Total Traded'] = shop['Open'] * shop['Volume']
jd['Total Traded'] = jd['Open'] * jd['Volume']
alibaba['Total Traded'] = alibaba['Open'] * alibaba['Volume']

# %%
plt.figure(figsize=(16, 8))
plt.plot(shop['Date'], shop['Total Traded'], label='Shopify (Open Price)')
plt.plot(jd['Date'], jd['Total Traded'], label='JD.com (Open Price)')
plt.plot(alibaba['Date'], alibaba['Total Traded'], label='Alibaba (Open Price)')
plt.title('Total Capital Traded Using Open Price')
plt.xlabel('Date')
plt.ylabel('Total Traded Value (USD)')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %% [markdown]
# This graph shows the same metric, but calculated using the opening price (Open × Volume) instead of the average price.
#
# Findings:
#
# The general shape of the trends matches Graph 1, but values are slightly more volatile in some segments, particularly for Alibaba and Shopify.
#
# Alibaba's spikes are pronounced in both graphs, but discrepancies between open vs avg-based values may indicate volatile opens or wide intraday price swings.
#
# JD.com remains the least volatile and consistently the lowest in terms of capital traded.

# %%
shop['Avg'] = (shop['High'] + shop['Low']) / 2
jd['Avg'] = (jd['High'] + jd['Low']) / 2
alibaba['Avg'] = (alibaba['High'] + alibaba['Low']) / 2

# %%
shop['Total Traded New'] = shop['Avg'] * shop['Volume']
jd['Total Traded New'] = jd['Avg'] * jd['Volume']
alibaba['Total Traded New'] = alibaba['Avg'] * alibaba['Volume']

# %%
# Shopify
plt.figure(figsize=(16, 6))
plt.plot(shop['Date'], shop['Total Traded'], label='Shopify (Open Price)')
plt.plot(shop['Date'], shop['Total Traded New'], label='Shopify (Avg Price)')
plt.title('Shopify: Total Traded Value (Open vs Avg Price)')
plt.xlabel('Date')
plt.ylabel('Total Traded Value (USD)')
plt.legend()
plt.grid(True)
plt.show()

# JD.com
plt.figure(figsize=(16, 6))
plt.plot(jd['Date'], jd['Total Traded'], label='JD.com (Open Price)')
plt.plot(jd['Date'], jd['Total Traded New'], label='JD.com (Avg Price)')
plt.title('JD.com: Total Traded Value (Open vs Avg Price)')
plt.xlabel('Date')
plt.ylabel('Total Traded Value (USD)')
plt.legend()
plt.grid(True)
plt.show()

# Alibaba
plt.figure(figsize=(16, 6))
plt.plot(alibaba['Date'], alibaba['Total Traded'], label='Alibaba (Open Price)')
plt.plot(alibaba['Date'], alibaba['Total Traded New'], label='Alibaba (Avg Price)')
plt.title('Alibaba: Total Traded Value (Open vs Avg Price)')
plt.xlabel('Date')
plt.ylabel('Total Traded Value (USD)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# The two lines mostly follow similar trends, confirming that open price and average price are often close

# %%
plt.figure(figsize=(16, 8))
plt.plot(shop['Date'], shop['Total Traded New'], label='Shopify (Avg Price)')
plt.plot(jd['Date'], jd['Total Traded New'], label='JD.com (Avg Price)')
plt.plot(alibaba['Date'], alibaba['Total Traded New'], label='Alibaba (Avg Price)')
plt.title('Total Capital Traded Using Average Price')
plt.xlabel('Date')
plt.ylabel('Total Traded Value (USD)')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %% [markdown]
# This plot shows the total daily capital traded for Shopify, JD.com, and Alibaba, calculated using the average price of each day ((High + Low) / 2 × Volume).
#
# Findings:
#
# Alibaba consistently leads in trading value, with multiple high-volume spikes, indicating strong investor activity or major events during specific periods.
#
# Shopify shows moderate fluctuations with a few significant spikes, especially toward late 2024 and mid-2025.
#
# JD.com trades at lower overall capital levels, with relatively stable and subdued patterns.
#
# Insight:
# Using average price provides a more stable estimate of traded value and smooths out volatility that may occur due to erratic opening prices.

# %% [markdown]
# ### **Moving Average**

# %% [markdown]
# Moving Average (MA) is widely used in technical analysis to smooth out the price by taking out the "noise" from random short-term price changes. Since it is based on historical prices, it is a lagging or trend-following indicator.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

for df in [shop, jd, alibaba]:
    df['MA50'] = df['Open'].rolling(window=50).mean()
    df['MA200'] = df['Open'].rolling(window=200).mean()

# %%
# Shopify
plt.figure(figsize=(16, 6))
plt.plot(shop['Date'], shop['Open'], label='Shopify Open')
plt.plot(shop['Date'], shop['MA50'], label='Shopify MA50')
plt.plot(shop['Date'], shop['MA200'], label='Shopify MA200')
plt.title('Shopify - Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid(True)
plt.show()

# JD.com
plt.figure(figsize=(16, 6))
plt.plot(jd['Date'], jd['Open'], label='JD Open')
plt.plot(jd['Date'], jd['MA50'], label='JD MA50')
plt.plot(jd['Date'], jd['MA200'], label='JD MA200')
plt.title('JD.com - Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid(True)
plt.show()

# Alibaba
plt.figure(figsize=(16, 6))
plt.plot(alibaba['Date'], alibaba['Open'], label='Alibaba Open')
plt.plot(alibaba['Date'], alibaba['MA50'], label='Alibaba MA50')
plt.plot(alibaba['Date'], alibaba['MA200'], label='Alibaba MA200')
plt.title('Alibaba - Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate correlation matrix
correlation = ret_comp.corr()

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt=".2f", square=True)
plt.title('Correlation Heatmap: Opening Prices')
plt.show()

# %% [markdown]
# JD.com and Alibaba show the strongest correlation (0.79), suggesting similar market behavior or regional economic influence.
#
# Shopify and JD.com have a moderate correlation (0.62), indicating some co-movement.
#
# Shopify and Alibaba have the weakest correlation (0.57), implying more independent price movements between these two

# %%
# Normalize the opening prices to 1 for comparison
normalized = ret_comp / ret_comp.iloc[0]

plt.figure(figsize=(16, 6))
for column in normalized.columns:
    plt.plot(normalized.index, normalized[column], label=column)

plt.title('Normalized Opening Prices (Base = 1)')
plt.xlabel('Date')
plt.ylabel('Relative Change')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %% [markdown]
# Alibaba shows the strongest growth overall, peaking near 1.9× its initial value around March 2025 — indicating the highest price appreciation among the three.
#
# JD.com also demonstrates positive growth, staying mostly above its base level (1.0) and peaking around 1.7×, suggesting consistent upward momentum.
#
# Shopify, although volatile, shows weaker overall performance — with dips below 0.8 and peaking slightly above 1.5. It demonstrates higher sensitivity to market shifts.

# %% [markdown]
# ### Candlestick chart for a specific date

# %%
pip install mplfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Green candles = closing price > opening price (bullish days)
#
# Red candles = closing price < opening price (bearish days)
#
# Wicks = intraday high and low
#
# Volume bars = trading activity beneath each candle

# %%
import mplfinance as mpf

# Select recent 30 days for clarity
shop_candle = shop.set_index('Date').copy()
shop_candle = shop_candle[['Open', 'High', 'Low', 'Close', 'Volume']]

# Optional: Filter last 30 trading days
shop_candle = shop_candle.last('30D')

# Plot candlestick chart
mpf.plot(shop_candle, type='candle', volume=True, style='yahoo',
         title='Shopify – Recent 30 Days Candlestick Chart',
         ylabel='Price (USD)', ylabel_lower='Volume')
# Out:
# /var/folders/m3/rn3tl7v91fx0t431cn6k65lc0000gn/T/ipykernel_48918/3731254064.py:8: FutureWarning: last is deprecated and will be removed in a future version. Please create a mask and filter using `.loc` instead
#   shop_candle = shop_candle.last('30D')

# %% [markdown]
# Around May 14–15, there was a strong price surge with high volume — could indicate news or earnings.
#
# The stock recovered after a mid-May dip, showing a short-term bullish reversal.
#
# Low volume near the end of May suggests reduced trading interest or consolidation.

# %%
import mplfinance as mpf

# Prepare JD.com data
jd_candle = jd.set_index('Date')[['Open', 'High', 'Low', 'Close', 'Volume']]
jd_candle = jd_candle.last('30D')

# Plot JD.com candlestick chart
mpf.plot(jd_candle, type='candle', volume=True, style='yahoo',
         title='JD.com – Recent 30 Days Candlestick Chart',
         ylabel='Price (USD)', ylabel_lower='Volume')

# Prepare Alibaba data
alibaba_candle = alibaba.set_index('Date')[['Open', 'High', 'Low', 'Close', 'Volume']]
alibaba_candle = alibaba_candle.last('30D')

# Plot Alibaba candlestick chart
mpf.plot(alibaba_candle, type='candle', volume=True, style='yahoo',
         title='Alibaba – Recent 30 Days Candlestick Chart',
         ylabel='Price (USD)', ylabel_lower='Volume')
# Out:
# /var/folders/m3/rn3tl7v91fx0t431cn6k65lc0000gn/T/ipykernel_48918/1453125323.py:5: FutureWarning: last is deprecated and will be removed in a future version. Please create a mask and filter using `.loc` instead
#   jd_candle = jd_candle.last('30D')
# /var/folders/m3/rn3tl7v91fx0t431cn6k65lc0000gn/T/ipykernel_48918/1453125323.py:14: FutureWarning: last is deprecated and will be removed in a future version. Please create a mask and filter using `.loc` instead
#   alibaba_candle = alibaba_candle.last('30D')

# %% [markdown]
# However, Alibaba's stock had a pretty big decrease after may 15

# %% [markdown]
# ## Basic Financial Analysis

# %% [markdown]
# By looking at a daily percentage change, it can be concluded stock's volatility and how risky it is. The formula is simple: more volatility = more risk.

# %% [markdown]
# Calculates daily percentage returns for each stock based on the previous day’s closing price.

# %%
import matplotlib.pyplot as plt

# Step 1: Calculate Daily Returns
shop['Returns'] = shop['Close'].pct_change()
jd['Returns'] = jd['Close'].pct_change()
alibaba['Returns'] = alibaba['Close'].pct_change()

# Step 2: Drop NaNs (first row will be NaN after pct_change)
shop = shop.dropna(subset=['Returns'])
jd = jd.dropna(subset=['Returns'])
alibaba = alibaba.dropna(subset=['Returns'])

# Step 3: Plot Histograms separately for clarity
plt.figure(figsize=(18, 5))

# Shopify
plt.subplot(1, 3, 1)
plt.hist(shop['Returns'], bins=50, alpha=0.7, color='blue')
plt.title('Shopify Daily Returns')
plt.xlabel('Return')
plt.ylabel('Frequency')

# JD.com
plt.subplot(1, 3, 2)
plt.hist(jd['Returns'], bins=50, alpha=0.7, color='orange')
plt.title('JD.com Daily Returns')
plt.xlabel('Return')

# Alibaba
plt.subplot(1, 3, 3)
plt.hist(alibaba['Returns'], bins=50, alpha=0.7, color='green')
plt.title('Alibaba Daily Returns')
plt.xlabel('Return')

plt.tight_layout()
plt.show()

# %% [markdown]
# Shopify
# The distribution is tall and narrow, centered around 0.
#
# Has a few extreme outliers, both positive and negative (±15–20%).
#
# Indicates moderate volatility with occasional sharp movements.
#
# 2. JD.com
# Similar shape to Shopify but more concentrated around 0.
#
# Fewer extreme returns, suggesting lower volatility.
#
# Reflects a relatively stable return pattern.
#
# 3. Alibaba
# Distribution is also centered around 0, slightly wider than JD.com.
#
# Shows more frequent small returns but also a few spikes.
#
# Indicates moderate volatility, but less than Shopify.

# %% [markdown]
# By plotting all 3 on the graph, let us compare them back to back.

# %%
import matplotlib.pyplot as plt

# Ensure returns are calculated and cleaned
shop['Returns'] = shop['Close'].pct_change()
jd['Returns'] = jd['Close'].pct_change()
alibaba['Returns'] = alibaba['Close'].pct_change()

# Align data on Date and drop NaNs from all
returns_df = pd.concat([
    shop[['Date', 'Returns']].set_index('Date').rename(columns={'Returns': 'Shopify'}),
    jd[['Date', 'Returns']].set_index('Date').rename(columns={'Returns': 'JD.com'}),
    alibaba[['Date', 'Returns']].set_index('Date').rename(columns={'Returns': 'Alibaba'})
], axis=1).dropna()

# Plot all returns together
plt.figure(figsize=(16, 6))
plt.plot(returns_df.index, returns_df['Shopify'], label='Shopify', alpha=0.7)
plt.plot(returns_df.index, returns_df['JD.com'], label='JD.com', alpha=0.7)
plt.plot(returns_df.index, returns_df['Alibaba'], label='Alibaba', alpha=0.7)
plt.axhline(0, linestyle='--', linewidth=1, color='black', alpha=0.5)
plt.title('Daily Returns Comparison')
plt.xlabel('Date')
plt.ylabel('Daily Return')
plt.legend(loc='upper right')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/m3/rn3tl7v91fx0t431cn6k65lc0000gn/T/ipykernel_48918/3796417002.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shop['Returns'] = shop['Close'].pct_change()
# /var/folders/m3/rn3tl7v91fx0t431cn6k65lc0000gn/T/ipykernel_48918/3796417002.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alibaba['Returns'] = alibaba['Close'].pct_change()

# %% [markdown]
# It’s the standard deviation of daily returns over a moving window (e.g., 7 days). below----->

# %%
import matplotlib.pyplot as plt

# Step 1: Ensure daily returns are calculated
shop['Returns'] = shop['Close'].pct_change()
jd['Returns'] = jd['Close'].pct_change()
alibaba['Returns'] = alibaba['Close'].pct_change()

# Step 2: Compute 7-day rolling standard deviation
shop['Volatility'] = shop['Returns'].rolling(window=7).std()
jd['Volatility'] = jd['Returns'].rolling(window=7).std()
alibaba['Volatility'] = alibaba['Returns'].rolling(window=7).std()

# Step 3: Align and plot
vol_df = pd.concat([
    shop[['Date', 'Volatility']].set_index('Date').rename(columns={'Volatility': 'Shopify'}),
    jd[['Date', 'Volatility']].set_index('Date').rename(columns={'Volatility': 'JD.com'}),
    alibaba[['Date', 'Volatility']].set_index('Date').rename(columns={'Volatility': 'Alibaba'})
], axis=1).dropna()

# Step 4: Plot
plt.figure(figsize=(16, 6))
plt.plot(vol_df.index, vol_df['Shopify'], label='Shopify', alpha=0.8)
plt.plot(vol_df.index, vol_df['JD.com'], label='JD.com', alpha=0.8)
plt.plot(vol_df.index, vol_df['Alibaba'], label='Alibaba', alpha=0.8)

plt.title('7-Day Rolling Volatility (Standard Deviation of Daily Returns)')
plt.xlabel('Date')
plt.ylabel('Volatility')
plt.legend(loc='upper right')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/m3/rn3tl7v91fx0t431cn6k65lc0000gn/T/ipykernel_48918/2092691547.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shop['Returns'] = shop['Close'].pct_change()
# /var/folders/m3/rn3tl7v91fx0t431cn6k65lc0000gn/T/ipykernel_48918/2092691547.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alibaba['Returns'] = alibaba['Close'].pct_change()
# /var/folders/m3/rn3tl7v91fx0t431cn6k65lc0000gn/T/ipykernel_48918/2092691547.py:9: SettingWithCopyWarning:
# ...

# %% [markdown]
# Shopify shows the highest volatility spikes, peaking above 10%, indicating it is the most sensitive and reactive stock among the three — especially during market turbulence.
#
# JD.com and Alibaba exhibit more stable volatility, generally staying below 5%, with Alibaba being the least volatile overall, making them relatively safer from a risk perspective.

# %% [markdown]
# ### Kernal Density Estimate type of graph

# %% [markdown]
# ### Boxplots on the returns

# %% [markdown]
# ### Scatterplot

# %%
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# Make sure returns are calculated
shop['Returns'] = shop['Close'].pct_change()
jd['Returns'] = jd['Close'].pct_change()
alibaba['Returns'] = alibaba['Close'].pct_change()

# Combine returns into one DataFrame
box_df = pd.concat([
    shop[['Date', 'Returns']].set_index('Date').rename(columns={'Returns': 'Shopify Ret'}),
    jd[['Date', 'Returns']].set_index('Date').rename(columns={'Returns': 'JD Ret'}),
    alibaba[['Date', 'Returns']].set_index('Date').rename(columns={'Returns': 'Alibaba Ret'})
], axis=1).dropna()

# ─────────────────────────────────────────────
# 1. KDE Plot (Distribution of Returns)
# ─────────────────────────────────────────────
plt.figure(figsize=(10, 6))
box_df['Shopify Ret'].plot(kind='kde', label='Shopify')
box_df['JD Ret'].plot(kind='kde', label='JD.com')
box_df['Alibaba Ret'].plot(kind='kde', label='Alibaba')
plt.title('KDE: Daily Returns Distribution')
plt.xlabel('Return')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# ─────────────────────────────────────────────
# 2. Box Plot (Spread and Outliers)
# ─────────────────────────────────────────────
plt.figure(figsize=(8, 6))
box_df.plot(kind='box', figsize=(8, 6))
plt.title('Box Plot: Daily Returns')
plt.ylabel('Return')
plt.grid(True)
plt.tight_layout()
plt.show()

# ─────────────────────────────────────────────
# 3. Scatter Matrix (Relationship Between Returns)
# ─────────────────────────────────────────────
scatter_matrix(box_df, figsize=(8, 8), alpha=0.2, hist_kwds={'bins': 50})
plt.suptitle('Scatter Matrix: Daily Returns')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/m3/rn3tl7v91fx0t431cn6k65lc0000gn/T/ipykernel_48918/1691372248.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shop['Returns'] = shop['Close'].pct_change()
# /var/folders/m3/rn3tl7v91fx0t431cn6k65lc0000gn/T/ipykernel_48918/1691372248.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alibaba['Returns'] = alibaba['Close'].pct_change()

# %% [markdown]
# 1. KDE Plot – Daily Returns Distribution
# All three stocks have returns centered near zero, with Alibaba showing the sharpest and tallest peak, indicating lower volatility.
#
# Shopify has a wider and flatter curve, suggesting more frequent extreme returns and thus higher risk.
#
# 📊 2. Box Plot – Return Spread and Outliers
# Shopify exhibits the widest spread and most extreme outliers, again confirming its high volatility.
#
# JD.com and Alibaba have similar interquartile ranges, but Alibaba shows less frequent large deviations, implying more stable returns.

# %% [markdown]
# Overall Project Findings:

# %% [markdown]
# This analysis compared Shopify, JD.com, and Alibaba using time series, statistical, and technical analysis. The key insights include:
#
# Shopify is the most volatile, with larger price swings and more risk—this is clear from its wide return distribution, high volatility spikes, and scattered return patterns.
#
# Alibaba shows stable growth with the lowest volatility, suggesting it's more consistent for conservative investors.
#
# JD.com sits in between—moderate volatility, correlated to Alibaba, and fairly stable returns.
#
# All three show returns centered around zero, but Shopify’s range makes it more attractive for short-term traders and risk-tolerant investors.
#
# Correlation and candlestick patterns suggest Shopify is decoupled from JD.com and Alibaba, which share some market behavior.

# %% [markdown]
# Shopify is a higher-risk, higher-reward stock, suitable for active traders or risk-tolerant investors looking for aggressive returns.

# %% [markdown]
# Alibaba appears to be the most stable and consistent performer, making it a suitable choice for long-term, conservative investors.
